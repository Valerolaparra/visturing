# %% [markdown]
# # Use example of visturing: PIQ
#
# This is a simple example where we use the metrics implemented in PIQ:
# https://github.com/photosynthesis-team/piq
# , and evaluate it in all the experiments proposed in:
# "A Turing Test for Artificial Nets devoted to Vision"
# https://www.frontiersin.org/journals/artificial-intelligence/articles/10.3389/frai.2025.1665874/abstract

# %%
# If the toolbox is not installed...
#!pip install git+https://github.com/Jorgvt/visturing.git

# %%
from visturing.properties import evaluate_all

# %%
# If the toolbox is not installed...
# !pip install piq
# Out:
# Requirement already satisfied: piq in /Users/valero/miniconda3/lib/python3.11/site-packages (0.8.0)
# Requirement already satisfied: torchvision>=0.10.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from piq) (0.17.0)
# Requirement already satisfied: numpy in /Users/valero/miniconda3/lib/python3.11/site-packages (from torchvision>=0.10.0->piq) (2.2.6)
# Requirement already satisfied: requests in /Users/valero/miniconda3/lib/python3.11/site-packages (from torchvision>=0.10.0->piq) (2.32.5)
# Requirement already satisfied: torch==2.2.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from torchvision>=0.10.0->piq) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from torchvision>=0.10.0->piq) (10.2.0)
# Requirement already satisfied: filelock in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (4.15.0)
# Requirement already satisfied: sympy in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (1.14.0)
# Requirement already satisfied: networkx in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (2.8.8)
# Requirement already satisfied: jinja2 in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (3.1.3)
# Requirement already satisfied: fsspec in /Users/valero/miniconda3/lib/python3.11/site-packages (from torch==2.2.0->torchvision>=0.10.0->piq) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from jinja2->torch==2.2.0->torchvision>=0.10.0->piq) (2.1.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/valero/miniconda3/lib/python3.11/site-packages (from requests->torchvision>=0.10.0->piq) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/valero/miniconda3/lib/python3.11/site-packages (from requests->torchvision>=0.10.0->piq) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/valero/miniconda3/lib/python3.11/site-packages (from requests->torchvision>=0.10.0->piq) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/valero/miniconda3/lib/python3.11/site-packages (from requests->torchvision>=0.10.0->piq) (2025.11.12)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/valero/miniconda3/lib/python3.11/site-packages (from sympy->torch==2.2.0->torchvision>=0.10.0->piq) (1.3.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import torch
from piq import DISTS, LPIPS, ssim

def evaluate_dist(ImA,ImB):
    # Imagenes dimensiones (Nims,H,W,C)
    # Normalizadas a [0,255]
    image_A = torch.Tensor(ImA/255).permute(0, 3, 1, 2)
    image_B = torch.Tensor(ImB/255).permute(0, 3, 1, 2)

    
    distances = np.zeros(ImA.shape[0])
    
    metric = LPIPS()

    for i in range(ImA.shape[0]):
        distances[i]: torch.Tensor = metric(image_A[i:i+1], image_B[0:1])
        #distances[i]: torch.Tensor = DISTS(image_A[i:i+1], image_B[0:1])
        #distances[i]: torch.Tensor = ssim(image_A[i:i+1], image_B[0:1], data_range=1.)

    return distances
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.5 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/valero/miniconda3/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/Users/valero/miniconda3/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/Users/valero/miniconda3/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/4s/2yd8m6kx4zn8143hhnlkqm600000gn/T/ipykernel_21616/3663739677.py", line 1, in <module>
#     import torch
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/torch/__init__.py", line 1471, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/valero/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/valero/miniconda3/lib/python3.11/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),

# %%
import numpy as np
# Testing the function behaviour
ImA = np.abs(255*np.random.rand(5,128,128,3))
ImB = np.abs(255*np.random.rand(1,128,128,3))

evaluate_dist(ImA,ImB)
# Out:
# /Users/valero/miniconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Users/valero/miniconda3/lib/python3.11/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# array([0.35416612, 0.36517096, 0.35851365, 0.36382648, 0.36158875])

# %%
# This function evaluates all the experiments proposed in the paper
# The first time it downloads the data, so it will take long
# If the data is already downloaded it should take a couple of seconds

results = evaluate_all(evaluate_dist,
             data_path="./Data/",
             gt_path="./Data/")
# Out:
# prop1 done
# prop2 done
# prop3_4 done
# /Users/valero/miniconda3/lib/python3.11/site-packages/visturing/properties/prop5.py:65: RuntimeWarning: divide by zero encountered in divide
#   diffs_inv = {k:v/diffs_a for k, v in diffs.items()}
# prop5 done
# prop6_7 done
# prop8 done
# prop9 done
# prop10 done

# %%
print(results['prop1']['corr'])
print(results['prop2']['correlations']['pearson_achrom'])
print(results['prop2']['correlations']['pearson_chrom'])
print(results['prop3_4']['pearson_corr'][0])
print(results['prop5']['person_corr'][0])
print(results['prop6_7']['pearson'][0])
print(results['prop8']['pearson'][0])
# Out:
# 0.6130796024184787
# 0.7536273531767794
# -0.13628408855357557
# 0.12729105163424437
# -0.1377676814400142
# -0.03646028419291269
# 0.3712516141088707
